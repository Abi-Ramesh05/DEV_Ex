# %% [markdown]
# <a href="https://colab.research.google.com/github/Abi-Ramesh05/DEV_Ex/blob/main/dev6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import folium
from IPython.display import display, IFrame
from google.colab import files

# Generate random data
np.random.seed(42)
num_points = 100
latitude = np.random.uniform(37.5, 38.5, num_points)
longitude = np.random.uniform(-123, -121, num_points)
value = np.random.randint(1, 100, num_points)

# Create DataFrame
df = pd.DataFrame({'Latitude': latitude, 'Longitude': longitude, 'Value': value})

# Basic stats
print("📊 Basic Statistics:")
print(df.describe())
print("\nMean:", df['Value'].mean())
print("Median:", df['Value'].median())
print("Mode:", df['Value'].mode().values)

# Create the map
base_map = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

for index, row in df.iterrows():
    popup_text = f"Value: {row['Value']}"
    folium.Marker([row['Latitude'], row['Longitude']], popup=popup_text).add_to(base_map)

# Save map to HTML
map_filename = 'interactive_map.html'
base_map.save(map_filename)

print(f"\n Map saved to '{map_filename}'")

# Display map inline
display(base_map)

# Provide download link
files.download(map_filename)
# Out:
# 📊 Basic Statistics:
#          Latitude   Longitude       Value
# count  100.000000  100.000000  100.000000
# mean    37.970181 -122.004337   50.670000
# std      0.297489    0.586223   28.640247
# min     37.505522 -122.986096    2.000000
# 25%     37.693201 -122.515991   27.000000
# 50%     37.964142 -121.988750   47.500000
# 75%     38.230203 -121.467633   72.750000
# max     38.486887 -121.028699   99.000000
#
# Mean: 50.67
# Median: 47.5
# Mode: [33]
#
#  Map saved to 'interactive_map.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18a1508a0e65eb645624132f57dad2cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18a1508a0e65eb645624132f57dad2cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18a1508a0e65eb645624132f57dad2cd = L.map(
#                 &quot;map_18a1508a0e65eb645624132f57dad2cd&quot;,
#                 {
#                     center: [37.970180743378215, -122.00433655368994],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5addc8979d906b74bfd56fc4861888c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5addc8979d906b74bfd56fc4861888c0.addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#             var marker_072dc09446f1249df717da66407b7322 = L.marker(
#                 [37.874540118847364, -122.93714162862653],
#                 {
# }
#             ).addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#         var popup_841927ba58a130bc79d2e143fdf34d31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cdad0b57dd6740c2c96de28e98b5f22 = $(`&lt;div id=&quot;html_0cdad0b57dd6740c2c96de28e98b5f22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 24.0&lt;/div&gt;`)[0];
#                 popup_841927ba58a130bc79d2e143fdf34d31.setContent(html_0cdad0b57dd6740c2c96de28e98b5f22);
#
#
#
#         marker_072dc09446f1249df717da66407b7322.bindPopup(popup_841927ba58a130bc79d2e143fdf34d31)
#         ;
#
#
#
#
#             var marker_0dc3ca174da6a38809f5047b57994729 = L.marker(
#                 [38.450714306409914, -121.72717917747244],
#                 {
# }
#             ).addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#         var popup_8cab270a87fcf0444f6e2deb5be42eb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc762687ab9720cb4319df25c33eef5e = $(`&lt;div id=&quot;html_bc762687ab9720cb4319df25c33eef5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 75.0&lt;/div&gt;`)[0];
#                 popup_8cab270a87fcf0444f6e2deb5be42eb3.setContent(html_bc762687ab9720cb4319df25c33eef5e);
#
#
#
#         marker_0dc3ca174da6a38809f5047b57994729.bindPopup(popup_8cab270a87fcf0444f6e2deb5be42eb3)
#         ;
#
#
#
#
#             var marker_72146a2c42fcafe8b58fb12c85aea514 = L.marker(
#                 [38.2319939418114, -122.37128803784735],
#                 {
# }
#             ).addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#         var popup_3a24f6ef73259fa82518648600cf74bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57ff3f054d1bd02aaea89a5bf2c1bd43 = $(`&lt;div id=&quot;html_57ff3f054d1bd02aaea89a5bf2c1bd43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 72.0&lt;/div&gt;`)[0];
#                 popup_3a24f6ef73259fa82518648600cf74bd.setContent(html_57ff3f054d1bd02aaea89a5bf2c1bd43);
#
#
#
#         marker_72146a2c42fcafe8b58fb12c85aea514.bindPopup(popup_3a24f6ef73259fa82518648600cf74bd)
#         ;
#
#
#
#
#             var marker_8c0acbf1e5500dd363b99ff0efdb31e1 = L.marker(
#                 [38.09865848419704, -121.9828586176706],
#                 {
# }
#             ).addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#         var popup_07313fa03a594e8235bffd52e3592687 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_047fdaa572b287944567d5f83c99b830 = $(`&lt;div id=&quot;html_047fdaa572b287944567d5f83c99b830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 36.0&lt;/div&gt;`)[0];
#                 popup_07313fa03a594e8235bffd52e3592687.setContent(html_047fdaa572b287944567d5f83c99b830);
#
#
#
#         marker_8c0acbf1e5500dd363b99ff0efdb31e1.bindPopup(popup_07313fa03a594e8235bffd52e3592687)
#         ;
#
#
#
#
#             var marker_2c0a215912f66b5e160b06cc52e79690 = L.marker(
#                 [37.65601864044244, -121.18486705214781],
#                 {
# }
#             ).addTo(map_18a1508a0e65eb645624132f57dad2cd);
#
#
#         var popup_ba1ba6848870a6a267778777250688e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1226a286a3439d9f89beacc9b948ad4 = $(`&lt;div id=&quot;html_a1226a286a3439d9f89beacc9b948ad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 38.0&lt;/div&gt;`)[0];
#                 popup_ba1ba6848870a6a267778777
